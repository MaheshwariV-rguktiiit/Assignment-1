# %% [markdown]
# <a href="https://colab.research.google.com/github/MaheshwariV-rguktiiit/Assignment-1/blob/master/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 1:**

# %% [markdown]
# 1.Install Jupyter notebook and run the first program and share the screenshot of the output.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
list1=[]
for n in range(2000, 3201):#Taken 2000 to 3201 because (both included)
    if (n%7==0) and (n%5!=0):
        list1.append(str(n))
print ("The numbers are\n",','.join(list1))
#taken example 2002 it is 2002/7 = 286 but not a multiple of 5 if we will divide it will give 2002/5 = 400.4 . easyily we can say last 1 digit is not multiple of 5 i.e not 5 or 0
# Out:
# The numbers are
#  2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %% [markdown]
# 3.Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
User_FirstName = input("Enter Your first name -")
User_LastName = input("Enter your Last name-")
User_reverseName='{1} {0}'.format(User_FirstName,User_LastName)#{ } .format(value) This method lets us concatenate elements within a string through positional formatting.
print("Now your first and last name is reversed -",User_reverseName)
# Out:
# Enter Your first name -Maheshwari
# Enter your Last name-Vadla
# Now your first and last name is reversed - Vadla Maheshwari

# %% [markdown]
# 4.Write a Python program to find the volume of a sphere with diameter 12 cm.
#
# Formula: V=4/3 * π * r 3

# %%
import math
r = float(12/2) # converting diameter to radius d/2 .The radius is half the diameter so you have a radius of 12/2 = 6 cm.
pi = math.pi
V = (float(4/3)*pi*r**3)
print('Volume of a sphere with diameter 12cm =', V)
# Out:
# Volume of a sphere with diameter 12cm = 904.7786842338603

# %% [markdown]
# **Task 2:**

# %% [markdown]
# 1.Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
# Below line read inputs from user using map() function 
a = list(map(int,input("\nEnter the numbers with comma separated : ").split(',')))

print("\n numbers List is - ", a)
# Out:
# Enter the numbers with comma separated : 1,2,4,6,8,90,100,79
#
#  numbers List is -  [1, 2, 4, 6, 8, 90, 100, 79]

# %% [markdown]
# Create the below pattern using nested for loop in Python.

# %%
number_pattern=5
for x in range(number_pattern):
    for y in range(x):
        print ('* ', end="")
    print('')

for x in range(number_pattern,0,-1):
    for y in range(x):
        print('* ', end="")
    print('')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# 3.Write a Python program to reverse a word after accepting the input from the user.

# %%
word=input('Enter Word: ')
print("After reversing a word:",word[::-1])
# Out:
# Enter Word: maheshwari
# After reversing a word: irawhseham

# %% [markdown]
# 4. Write a Python Program to print the given string in the format specified in the ​sample output.
#
#  WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens

# %%
given_string = "WE, THE PEOPLE OF INDIA,{}having solemnly resolved to constitute India into a SOVEREIGN,{}SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC{}and to secure to all its citizens{}"
output_string = given_string.format('\n\t','!\n\t\t','\n\t\t','')
print(output_string)
# Out:
# WE, THE PEOPLE OF INDIA,
# 	having solemnly resolved to constitute India into a SOVEREIGN,!
# 		SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 		and to secure to all its citizens
